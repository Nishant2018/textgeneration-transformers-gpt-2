# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    🔥🔥TEXT-GENERATOR||TRANSFORMERS||GPT-2🔥🔥
# </div>

# %% [markdown]
# ![](https://fireflies.ai/blog/content/images/2022/12/What-is-GPT.jpg)

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨GPT-2✨✨
# </div>

# %% [markdown]
# ### GPT-2 (Generative Pretrained Transformer 2):
#
# - **Overview:**
#   - GPT-2 is an advanced language model developed by OpenAI, serving as a predecessor to GPT-3.
#   - It is based on the Transformer architecture, specifically designed for natural language processing tasks.
#
# - **Architecture:**
#   - GPT-2 utilizes a multi-layer transformer decoder architecture, consisting of attention mechanisms and feedforward neural networks.
#   - The decoder is trained to generate sequences of tokens, making it suitable for tasks like text generation, completion, and summarization.
#
# - **Scalability:**
#   - GPT-2 is notable for its scalability, with models ranging from 117M to 1.5B parameters across different versions.
#   - Larger models tend to capture more complex language patterns and contexts, leading to improved performance but requiring more computational resources.
#
# - **Pretraining:**
#   - GPT-2 is pretrained on a diverse corpus of text data, such as books, articles, and websites, using unsupervised learning objectives.
#   - Pretraining tasks include masked language modeling (predicting masked words) and next sentence prediction (predicting if a sentence follows another).
#
# - **Capabilities:**
#   - **Text Generation:** GPT-2 excels in generating coherent and contextually relevant text, often used for creative writing, story generation, and dialogue completion.
#   - **Language Understanding:** It demonstrates strong language understanding capabilities, allowing it to comprehend and respond to input prompts in a meaningful way.
#
# - **Fine-Tuning:**
#   - Users can fine-tune GPT-2 on specific tasks or datasets by providing task-specific training data and objectives.
#   - Fine-tuning enables GPT-2 to adapt to particular domains or tasks, improving its performance and accuracy.
#
# - **Conditional Generation:**
#   - GPT-2 supports conditional generation, where users can provide conditioning inputs or prompts to guide the generated text in a specific direction.
#   - Conditioning inputs can include keywords, style tokens, or context sentences to influence the generated output.
#
# - **Controlled Text Generation:**
#   - Techniques such as temperature scaling, top-k sampling, and nucleus sampling can be applied to control the diversity, creativity, and coherence of the generated text.
#   - These methods allow users to adjust the randomness and selection of tokens during text generation.
#
# - **Applications:**
#   - GPT-2 finds applications in various domains, including content generation for social media, chatbots, virtual assistants, and creative writing platforms.
#   - It is also used for text completion tasks, summarization, sentiment analysis, and generating human-like responses in conversational AI systems.
#
# - **Ethical Considerations:**
#   - As with any powerful language model, ethical considerations regarding bias, fairness, safety, and misuse are important.
#   - OpenAI initially released GPT-2 in stages, citing concerns about potential misuse for generating misleading or harmful content.
#
# GPT-2 is a highly capable language model known for its versatility, scalability, and performance in various natural language processing tasks, making it a valuable tool for researchers, developers, and AI enthusiasts.

# %% [markdown]
# ![](https://www.researchgate.net/publication/345654307/figure/fig2/AS:956166976839681@1604979380774/Architecture-of-the-GPT-2-Transformer-model.ppm)

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨TRANSFORMERS || LLM✨✨
# </div>

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:1400/1*nbyKjUXHHvJesxAT0aCenQ.jpeg)

# %% [markdown]
# ### Transformers:
#
# - **Overview:**
#   - Transformers are a type of deep learning architecture that has revolutionized natural language processing (NLP) tasks.
#   - They are based on the attention mechanism, allowing models to capture long-range dependencies and context in text data effectively.
#
# - **Architecture:**
#   - Transformers consist of encoder and decoder layers, each containing self-attention mechanisms and feedforward neural networks.
#   - The encoder processes input sequences, while the decoder generates output sequences, making transformers suitable for sequence-to-sequence tasks.
#
# - **Self-Attention Mechanism:**
#   - Self-attention allows the model to weigh the importance of different words in a sequence, capturing relationships and dependencies.
#   - It computes attention scores based on the similarity between words in the input sequence, facilitating context understanding.
#
# - **Multi-Head Attention:**
#   - Transformers often employ multi-head attention, where attention mechanisms operate in parallel with multiple attention heads.
#   - This enables the model to learn different aspects of context and relationships simultaneously, enhancing representational power.
#
# - **Positional Encoding:**
#   - Transformers incorporate positional encoding to inject positional information into the input sequences.
#   - Positional encodings help the model understand the order of words in a sequence, addressing the lack of inherent positional information in self-attention.
#
# - **Applications:**
#   - Transformers have been widely adopted in NLP tasks such as machine translation, text generation, sentiment analysis, question answering, and summarization.
#   - They have also been applied to image processing tasks and other domains beyond NLP, showcasing their versatility and effectiveness.
#
# ### Language Models (LLMs):
#
# - **Overview:**
#   - Language Models (LLMs) are models designed to understand and generate human language, capturing semantic and syntactic structures.
#   - They are trained on large text corpora using unsupervised learning objectives, learning language patterns and representations.
#
# - **Pretraining and Fine-Tuning:**
#   - LLMs undergo pretraining on vast amounts of text data, where they learn general language understanding and context modeling.
#   - Fine-tuning involves adapting the pretrained LLMs to specific tasks or domains by providing task-specific data and objectives.
#
# - **Types of LLMs:**
#   - **Autoregressive Models:** Models like GPT-2 and GPT-3 generate text sequentially, predicting the next token given previous tokens.
#   - **Bidirectional Models:** Models like BERT and RoBERTa capture bidirectional context by considering both left and right context during training.
#
# - **Capabilities:**
#   - LLMs excel in various NLP tasks, including text generation, translation, sentiment analysis, named entity recognition (NER), summarization, and dialogue systems.
#   - They demonstrate strong language understanding, enabling them to comprehend and generate coherent text across diverse domains.
#
# - **Ethical Considerations:**
#   - As powerful language models, LLMs raise ethical considerations regarding bias, fairness, safety, privacy, and responsible AI deployment.
#   - Ensuring fairness, transparency, and accountability in LLM development and usage is crucial for ethical AI practices.
#
# - **Advancements:**
#   - Recent advancements in LLMs include models like GPT-3 with large-scale parameters, T5 with text-to-text transformations, and RoBERTa with optimization strategies.
#   - These advancements have pushed the boundaries of NLP performance, scalability, and adaptability to various tasks and domains.
#
# Transformers represent a foundational architecture in deep learning, particularly in NLP, while Language Models (LLMs) leverage transformer-based architectures to achieve advanced language understanding and generation capabilities across diverse NLP tasks and applications.

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨IMPORTING LIBRARIES✨✨
# </div>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import warnings
from transformers import GPT2LMHeadModel, GPT2Tokenizer, pipeline
# Out:
# 2024-03-26 21:11:49.355583: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 21:11:49.355758: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 21:11:49.526539: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨Taking Input✨✨
# </div>

# %%
text = "Once upon a time, in a magical forest, there lived a curious elf named Elara. She had"
#text= input("Enter your sentence here\n")

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    📌📌Function To Generate Text📌📌
# </div>

# %%
def generate_text(prompt):
    generator = pipeline('text-generation', model='gpt2')
    generated_text = generator(prompt, max_length=200, num_return_sequences=1, truncation=True)

    print(generated_text[0]['generated_text'])

# %%
generate_text(text)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Once upon a time, in a magical forest, there lived a curious elf named Elara. She had spent her life fighting in secret to obtain rare elf artifacts. When it was learned of by the mages who were involved in the magic, Elara took some of her magic power and transformed into a new magic item named "Mead of Ice", which she used in combat to heal herself. This was much needed magic. Once Elara was healed and returned to her village, Elara used her old magic as she left the village to seek out her future. She has been very diligent and has never left the house of anyone in the past to attempt to save her former village. She has always lived in a forest. She always remembers her old magic.
#
# The curse that plagued the village of Elara was one of the major mysteries that led her to the village. One time when Elara was young she fell asleep while talking about she had lost her magic. Elara had been asleep

# %% [markdown]
# ![](https://www.pngitem.com/pimgs/m/151-1519293_clip-art-thank-you-sir-hd-png-download.png)
